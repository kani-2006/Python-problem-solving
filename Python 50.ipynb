# %%
print("welcome")
# Out:
# welcome

# %%
a=input("Please enter a word: ")
print(a)
# Out:
# Please enter a word: KIT
# KIT

# %%
a=input("Enter the message: ")
print(a)
# Out:
# Enter the message: CM C.Joseph Vijay
# CM C.Joseph Vijay

# %%
a=int(input("Enter the integer: "))
print(a)
# Out:
# Enter the integer: 23
# 23

# %%
#print the given fractional number.
d=13.03
print(d)
# Out:
# 13.03

# %%
a=30.9810
print(round(a,2))
# Out:
# 30.98

# %%
a=236
print(hex(a),oct(a))
# Out:
# 0xec 0o354

# %%
h="0xAA"
print(int(h,16))
# Out:
# 170

# %%
o="0o56"
print(int(o, 8))
# Out:
# 46

# %%
a='K'
print(ord(a))
# Out:
# 75

# %%
a=67
print(chr(a))
# Out:
# C

# %%
a=30
b=20
print(a,b)
# Out:
# 30 20

# %%
a=30
b=20
print(a, "\t", b)
# Out:
# 30 	 20

# %%
a='K'
print("'" + a + "'")
# Out:
# 'K'

# %%
print("\"Hello\" \"World\"")
# Out:
# "Hello" "World"

# %%
d=input("Enter day: ")
m=input("Enter month: ")
y=input("Enter year: ")

print(d+ "/" + m+ "/" + y)
# Out:
# Enter day: Tuesday
# Enter month: May
# Enter year: 2006
# Tuesday/May/2006

# %%
a=int(input("Enter number: "))
print("+",a)
# Out:
# Enter number: 20
# + 20

# %%
import sys
a='A'
n=13
f=20.5
d=10.20307

print("Size of char:", sys.getsizeof(a))
print("Size of int:", sys.getsizeof(n))
print("Size of float:", sys.getsizeof(f))
print("Size of double:", sys.getsizeof(d))
# Out:
# Size of char: 42
# Size of int: 28
# Size of float: 24
# Size of double: 24

# %%
a=18
n="Kanishka"

print("Roll No:",a, ", Name:", n)
# Out:
# Roll No: 18 , Name: Kanishka

# %%
print("Tamil   : 93")
print("English : 86")
print("Maths   : 83")
print("Science : 89")
print("Social  : 92")
# Out:
# Tamil   : 93
# English : 86
# Maths   : 83
# Science : 89
# Social  : 92

# %%
b=input("Enter your blood group: ")
print("Your blood group is:", b)
# Out:
# Enter your blood group: b+ve
# Your blood group is: b+ve

# %%
from datetime import datetime
a=datetime.now().strftime("%H:%M:%S")
print(a)
# Out:
# 04:03:40

# %%
from datetime import datetime
l=datetime.now().strftime("%H:%M:%S")
print(l)
# Out:
# 04:02:51

# %%
print("He\nscored\n443")
# Out:
# He
# scored
# 443

# %%
a=int(input())
b=int(input())
print("Addition:",a+b)
print("Difference:",a-b)
print("Product:",a*b)
print("Remainder:",a%b)
print("Quotient:",a//b)
# Out:
# 18
# 23
# Addition: 41
# Difference: -5
# Product: 414
# Remainder: 18
# Quotient: 0

# %%
#swapping two var using third variable
a=int(input("Enter first number: "))
b=int(input("Enter second number: "))
temp=a
a=b
b=temp
print("After swapping:")
print("a =", a)
print("b =", b)
# Out:
# Enter first number: 18
# Enter second number: 23
# After swapping:
# a = 23
# b = 18

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
a = a + b
b = a - b
a = a - b
print("After swapping:")
print("a =", a)
print("b =", b)
# Out:
# Enter first number: 18
# Enter second number: 23
# After swapping:
# a = 23
# b = 18

# %%
#print the last digit of given number N
n= int(input("Enter a number: "))
last_digit=n% 10
print("Last digit of", n, "is", last_digit)
# Out:
# Enter a number: 2318
# Last digit of 2318 is 8

# %%
# print the all digits Except last digit of given number N
N = int(input("Enter a number: "))
digits = N // 10
print("All digits of", N, "except last digit:", digits)
# Out:
# Enter a number: 7346
# All digits of 7346 except last digit: 734

# %%
# print the middle digit of a 3-digit number.
N = int(input("Enter a 3-digit number: "))
middle_digit = (N % 100) // 10
print("Middle digit of", N, "is", middle_digit)
# Out:
# Enter a 3-digit number: 456
# Middle digit of 456 is 5

# %%
# print the absolute value of a given number.
N = int(input("Enter a number: "))
absolute_value = abs(N)
print("Absolute value of", N, "is", absolute_value)
# Out:
# Enter a number: 732
# Absolute value of 732 is 732

# %%
# print the square of a given number
N = int(input("Enter a number: "))
square = N ** 2
print("Square of", N, "is", square)
# Out:
# Enter a number: 55
# Square of 55 is 3025

# %%
# print the cube of a given number
N = int(input("Enter a number: "))
cube = N ** 3
print("Cube of", N, "is", cube)
# Out:
# Enter a number: 4
# Cube of 4 is 64

# %%
#average of three numbers
a=int(input())
b=int(input())
c=int(input())
print(a+b+c/3)
# Out:
# 3
# 2
# 1
# 5.333333333333333

# %%
#equal or not
a=int(input())
b=int(input())
if a==b:
  print("equal")
else:
  print("not equal")
# Out:
# 3
# 5
# not equal

# %%
#Program to check if a number is power of 2 using bitwise AND.
num = int(input("Enter a number: "))

if num > 0 and (num & (num - 1)) == 0:
    print("Power of 2")
else:
    print("Not a power of 2")
# Out:
# Enter a number: 5
# Not a power of 2

# %%
num = int(input("Enter a number: "))

if num > 0:
    print("Positive")
elif num < 0:
    print("Negative")
else:
    print("Zero")
# Out:
# Enter a number: 267
# Positive

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if a > b and a > c:
    print("Greatest number is", a)
elif b > c:
    print("Greatest number is", b)
else:
    print("Greatest number is", c)
# Out:
# Enter first number: 5
# Enter second number: 6
# Enter third number: 3
# Greatest number is 6

# %%
marks = int(input("Enter marks: "))

if marks >= 35:
    print("Pass")
else:
    print("Fail")
# Out:
# Enter marks: 75
# Pass

# %%
#area of rectangle,square,circle and traingle
#rectangle
l=int(input())
b=int(input())
print("area of rectangle:",l*b)

#square
a=int(input())
print("area of square:",a*a)

#circle
r=int(input())
print("area of circle:",3.14*r*r)

#triangle
b=int(input())
h=int(input())
print
# Out:
# 4
# 5
# area of rectangle: 20
# 5
# area of square: 25
# 4
# area of circle: 50.24
# 54
# 5
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
import math

x1 = int(input("Enter x1: "))
y1 = int(input("Enter y1: "))
x2 = int(input("Enter x2: "))
y2 = int(input("Enter y2: "))

distance = math.sqrt((x2 - x1)**2 + (y2 - y1)**2)

print("Distance =", distance)
# Out:
# Enter x1: 5
# Enter y1: 6
# Enter x2: 7
# Enter y2: 8
# Distance = 2.8284271247461903

# %%
#fahrenheit to celcius
fah=float(input("enter the fahrenheit:"))
cel=(fah-32)*5/9
print(cel)
# Out:
# enter the fahrenheit:78
# 25.555555555555557

# %%
#celcius to fahrenheit
cel=float(input("enter the celcius:"))
fah=(cel*9/5)+32
print(fah)
# Out:
# enter the celcius:9
# 48.2

# %%
#perimeter

#circumference of circle
r=int(input())
print("perimeter of circle:",2*3.14*r)

#rectangle
l=int(input())
b=int(input())
print("perimeter of rectangle:",2*(l+b))

#square
a=int(input("enter the side:"))
print("perimeter of square:",4*a)
# Out:
# 98
# perimeter of circle: 615.44
# 8
# 6
# perimeter of rectangle: 28
# enter the side:4
# perimeter of square: 16

# %%
#cubee
#surface area
a=int(input())
print("surface area of cube:",6*a*a)

#volume
print("volume of cube:",a*a*a)

#perimeter
print("perimeter if cube:",12*a)
# Out:
# 5
# surface area of cube: 150
# volume of cube: 125
# perimeter if cube: 60

# %%
#cuboid
#surface area
l=int(input())
b=int(input())
h=int(input())
print("surface area of cuboid:",2*(l*b+b*h+l*h))
#volume
print("volume of cuboid:",l*b*h)
# Out:
# 2
# 2
# 1
# surface area of cuboid: 16
# volume of cuboid: 4

# %%
#sphere
#surface area
r=int(input())
print("surface area of sphere:",4*3.14*r*r)

#volume
print("volume of sphere:",4/3*3.14*r*r*r)
# Out:
# 56
# surface area of sphere: 39388.16
# volume of sphere: 735245.6533333333

# %%
1#cylinder
#surface
r=int(input())
h=int(input())
print("surface area of cylinder:",2*3.14*r*(r+h))

#volume
print("volume of cylinder:",3.14*r*r*h)
# Out:
# 23
# 8
# surface area of cylinder: 4477.64
# volume of cylinder: 13288.48

# %%
#Print Price After Discount
price=float(input("enter the price:"))
discount=float(input("enter the discount:"))
print("price after discount:",price-price*discount/100)
# Out:
# enter the price:400
# enter the discount:50
# price after discount: 200.0

# %%
#minutes to seconds
minutes=int(input("enter the minutes:"))
print(minutes*60,"seconds")
# Out:
# enter the minutes:40
# 2400 seconds

# %%
bill = int(input("Enter total bill amount: "))

share = bill / 3

print("Each friend should pay =", share)
# Out:
# Enter total bill amount: 30
# Each friend should pay = 10.0

# %%
#calculation of distance travlled
speed=int(input("enter the speed:"))
time=int(input("enter the time:"))
print("distance travlled:",speed*time)
# Out:
# enter the speed:567
# enter the time:456
# distance travlled: 258552

# %%
#
char=input()
if char.isdigit():
  print("char is digit")
elif char.isalpha():
  print("char is alphabet")
else:
  print("spl symbol")
# Out:
# 567
# char is digit

# %%
number=int(input("enter the number: "))
if number>=0 and number <= 9:
  print("single digit number")
elif number >=10 and number<= 99:
  print("two digit number")
elif number >= 100 and number <= 999:
  print("Three digit number")
else:
  print("More than three digit number")
# Out:
# enter the number: 3209
# More than three digit number

# %%
num=int(input("enter the 4 digit nmber:"))

frst_two=num//100
last_two=num%100

if frst_two==last_two:
  print("frst and last two digits are equal")
else:
  print("not equal")
# Out:
# enter the 4 digit nmber:4567
# not equal

# %%
n=int(input())
match n:
  case i if n>=90:print("A")
  case i if 75 <=n <90:print("B")
  case i if 60<=n<75:print("C")
  case i if  35<=n<60:print("D")
  case _:print("Fail")
# Out:
# 60
# C

# %%
#operators

l=int(input())
b=int(input())
perimeter=2*(l+b)
area=l*b
print(area,perimeter)
# Out:
# 5
# 6
# 30 22
